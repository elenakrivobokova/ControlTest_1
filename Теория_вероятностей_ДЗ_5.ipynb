# %% [markdown]
# <a href="https://colab.research.google.com/github/elenakrivobokova/ControlTest_1/blob/main/%D0%A2%D0%B5%D0%BE%D1%80%D0%B8%D1%8F_%D0%B2%D0%B5%D1%80%D0%BE%D1%8F%D1%82%D0%BD%D0%BE%D1%81%D1%82%D0%B5%D0%B9_%D0%94%D0%97_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. ЗАДАЧА**
# Когда используется критерий Стьюдента, а когда Z –критерий?

# %% [markdown]
# Z- критерий используется для нормально распределенной генеральной совокупности, если известно среднее квадратичное отклонение (сигма) генеральной совокупности.
# Данный критерий используется для проверки гипотезы о нормальности распределения данных в выборке с известным значением среднего значения.Это позволяет оценить точность среднего значения измерения в генеральной совокупности, а также понять, насколько данные в выборке представляют собой нормальное распределение.
#
# Критерий Стьюдента t используется, если среднее квадртичное отклонение не известно. Сигму рассчитывают по выборке через формулу для несмещенного стандартного отклонения. Этот критерий применяют для сравнения средних значений двух групп. Он позволяет оценить, насколько средние значения двух групп отличаются.
#
# Z-критерий применяется для случаев, когда размер выборки велик, t-критерий подходит для случаев, когда размер образца мал.

# %% [markdown]
# **2. ЗАДАЧА**
# Проведите тест гипотезы. Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм. Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр оказался равным 17.5 мм, а дисперсия известна и равна 4 кв. мм.

# %% [markdown]
# Дано:
#
# μ (средний диаметр)  - 17
#
# X (средний диаметр в выборке)- 17,5
#
# a (уровень значимости)- 0,05
#
# n (объем выборки)- 100
#
# sigma (дисперсия) - 4 (т.е. 𝞼 (среднее квадратичное отклонение - 2)
#
# Решение:
# 1. сформулируем нулевую и альтернативную гипотезы:
#
# H1 = HO
# H1 > H0 (т.к. X > μ)
#
# 2. поскольку нам известна 𝞼, расчитаем наблюдаемый Z критерий:
#
# Z = (17,5 - 17) / (2 / √100) = 2,5
#
# 3. найдем табличное значение уровня статистической значимости α (0,05): 1,645
#
# 4. сравним значения расчетного Z-критерия с табличным:
#
# 2,5 > 1,645
#
# ВЫВОД: принимаем альтернативную гипотезу - средний диаметр шариков для подшипников больше 17 мм.

# %% [markdown]
# **3. ЗАДАЧА**
# Проведите тест гипотезы. Продавец утверждает, что средний вес пачки печенья составляет 200 г. Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет: 202, 203, 199, 197, 195, 201, 200, 204, 194, 190. Известно, что их веса распределены нормально. Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%? (Провести двусторонний тест.)

# %% [markdown]
# Дано:
#
# μ (средний вес) - 200
#
# a (уровень значимости)- 0,01 (100% - 99% =1%)
#
# n (объем выборки)- 10 (202,203,199,197,185,201,200,204,194,190)
#
#
# Решение:
#
# 1. определим среднее арифметическое выборки (равно математическому ожиданию при нормальном распределении):
#
# X = (202+203+199+197+185+201+200+204+194+190) = 197,5
#
#
# 2. сформулируем нулевую и альтернативную гипотезы:
#
# H1 = HO
# H1 != H0
#
# 3. поскольку нам не известна сигма генеральной совокупности, для расчета наблюдаемого критерия используем критерий Стьюдента t:
#
# - тест двусторонний, значит a = a/2 = 0,005;
#
# - объем выборки был 10. Т.е. 9 степеней свободы;
#
# - табличное значение критерия значимости равно **3,250**.
#
# 4. найдем расчетное значение наблюдаемого критерия:
#
# расчитаем несмещенное среднее квадратичное отклонение: https://docs.google.com/spreadsheets/d/1DAA_us5r_14jLVk_LX7GG2UtERD_CVQdjhiMLyCaAOc/edit#gid=1367192853
#
# 𝞼 = 6,13
#
# Z = (197,5-200) / (6,13 / √10) = 2,5 * 6,13 / 3,16 = **-1,29**
#
# 5. сравним значения расчетного t-критерия с табличным:
#
# |-1,29| < 3,250
#
# ВЫВОД: принимаем нулевую гипотезу: μ = 200 на уровне значимости a = 0,1

# %% [markdown]
# **4. ЗАДАЧА**
# Есть ли статистически значимые различия в росте дочерей? Рост матерей 172, 177, 158, 170, 178,175, 164, 160, 169, 165 Рост взрослых дочерей: 173, 175, 162, 174, 175, 168, 155, 170, 160

# %%
import math
import numpy as np
from scipy import stats

mothers=np.array([172,177,158,170,178,175,164,160,169,165])
daughters=np.array([173,175,162,174,175,168,155,170,160,163])

stat, p = stats.ttest_rel(mothers, daughters)
print('Statistics=%.3f, p=%.3f' % (stat, p))

a=float(input("Введите уровень значимости: "))
if p>a:
    print("Статистически значимых различий в росте матерей и дочерей нет")
else:
    print("Есть статистически значимые различия в росте матерей и дочерей")
# Out:
# Statistics=0.665, p=0.523
# Введите уровень значимости: 0.05
# Статистически значимых различий в росте матерей и дочерей нет
